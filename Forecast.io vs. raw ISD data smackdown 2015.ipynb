# %%
import forecastio
import numpy as np
import pandas as pd
import seaborn as sns
# %pylab inline

sns.set_context("notebook")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Integrating Weather Data into PE Analytics
# ==========================================
#
# Motivation
# ----------
# Many of the use cases for the PE Analytics project entail making inferences about variables that are plausibly effected by weather conditions. Some examples include:
#
# * **Equipment lifetime**
# * **Job execution time**
# * **Reducible idling time**
#
# If we can incorporate hi-resolution weather data into our models, our insights will be more accurate and we will be able to make more confident inferences.
#
#
#
# <img src="http://static1.squarespace.com/static/5413288ee4b01e9509f3a75c/541328a5e4b0b21cb97a482c/547271abe4b00af97ef54edf/1416793987098/?format=1000w" style="width: 80px; float: none;" align="left">
#
# Forecast.io
# -----------
# Forecast.io is application that purports to offer present and historical queries for rich weather information, plus forecasts, from any coordinates on the globe. We will evaluate this claim below. The platform incorporates data from a large variety of sources, including several from the NCDC and other sources around the globe.
#
# Forecast.io is accessed via a well-documented [REST API](https://developer.forecast.io/) and is free for the first 1000 calls / day. After that they start charging a fraction of a cent.
#
# They also make a pretty sweet iPhone app called [Dark Sky](http://darkskyapp.com/), which will ping you ten minutes before it starts raining.
#
# <img src="http://www.ncdc.noaa.gov/profiles/ncdc/themes/ncdc/images/logos/noaa_logo.png" style="width: 150px; float: none;"  align="left">
#
#
# NOAA / NCDC
# -----------
# The National Oceanic and Atmospheric Administration is really good about opening up data collected by its weather stations positioned around the country to the public. A wide variety of data products are available for consumption, from very coarse (day-level quality-controlled summaries) to very fine-grained (minute-level weather data from [ASOS](http://www.nws.noaa.gov/ost/asostech.html) stations maintained by the NWS, FAA, and DoD).
#
# The primary NCDC source that we have proposed to use for fine-grained US weather data is the [ISD](http://www.ncdc.noaa.gov/isd) (Integrated Surface Database). The ISD goes down to 20-minute timesteps in most places and itself incorporates data from several different types of weather stations, located thorughout the country. ISD is sort of the "Gold Standard" for NCDC weather data -- comprehensive, pretty well quality-controlled, reliable.
#
# You can pull data from their ftp server, located at [ftp.ncdc.noaa.gov](ftp://ftp.ncdc.noaa.gov). There are usually PDFs that describe the format (sometimes arcane) of whatever you're looking at.
#
# The Questions at Hand
# ---------------------
# * **Is Forecast.io a suitable proxy for raw ISD data?**
#   This would be nice, because Forecast.io is much easier to get at than ISD data, is pre-organized and -processed, covers more territory (the whole earth(!)) and supports real-time querying.
#
# * **Do Forecast.io's interpolation strategies produce credible estimates?**
#   Forecast.io's innovation is that they are able to produce a "smooth surface" describing the weather conditions over a given geo area and time. Using historical data from ISD, we can design an experiment to make sure they're not pulling our leg.
#
# * **Are Forecast.io's *forecasts* credible?**
#   Using historical queries and historical ISD data, we can test Forecast.io's predictions in a few places and evaluate their performance.

# %% [markdown]
# To business!
# ------------
# We'll begin by looking at the ISD data, and getting it into shape so that we can compare with Forecast.io.

# %%
# I've pulled a bunch of historical ISD data from Colorado, and cleaned it up for inspection.
# The git repo containing the R script and bash scripts used to download and clean is here:
# https://github.com/hack-c/weathergrab
# No promises of portability for the shell scripting, but the R script that pulls the data doesn't have any dependencies.

stations = pd.read_csv("data/stations.csv")
stations.columns = map(str.lower, stations.columns)  # lowercase column names

# %%
stations.head()
# Out:
#    usafid   wban    yr     lat     long  elev
# 0  720262  94076  2015  40.054 -106.368  2259
# 1  720385    419  2015  39.800 -105.767  4113
# 2  720385  99999  2015  39.800 -105.767  4113
# 3  720528  99999  2015  38.817 -106.117  2423
# 4  720529    429  2015  38.233 -108.567  1811

# %% [markdown]
# **Let's find a few stations that are closely clustered.**

# %%
plt.scatter(stations["long"], stations["lat"])

# %% [markdown]
# **Looks about right. (Interactive map [here](http://www.openheatmap.com/view.html?map=TrochlearsSpladKickboxer))**
#
# Seems there's a solid cluster in the NE corner of the map. We'll use that in a minute.
#
# <img style="float: left" src="https://pbs.twimg.com/media/CCGXU0ZWYAAkIMK.png">

# %% [markdown]
# **Now to look at some of the actual time series weather data for these stations.**
#
# The ISD data I pulled is organized by year and station in csv files, with filenames formatted like the below.
#
# We'll build a new column `filename` for our "index" dataframe (`stations`), and then load in timeseries data from the stations in the northeast corner of the map.

# %%
ls data/csv/ | head
# Out:
# 720262-94076-2015.csv
# 720385-00419-2015.csv
# 720385-99999-2015.csv
# 720528-99999-2015.csv
# 720529-00429-2015.csv
# 720531-99999-2015.csv
# 720532-00159-2015.csv
# 720532-99999-2015.csv
# 720533-99999-2015.csv
# 720534-99999-2015.csv

# %% [markdown]
# So let's construct a column with the filename for each station, for easy accessing.

# %%
def construct_filename(s):
    """
    Format the filename for a given station, 
    coercing types and padding with zeros where necessary.
    """
    usafid = "{0:06d}".format(int(s.usafid))  # use new python string formatting
    wban   = "{0:05d}".format(int(s.wban))
    return "{usafid}-{wban}-2015.csv".format(usafid=usafid, wban=wban)
    
# in pandas, applying a function across each value of a Series is easy.
# use the apply() method, passing it a function (like the above).
# "look ma, no for loops!"

stations['filename'] = stations.apply(construct_filename, axis=1)
stations.index = stations['filename']  # use this as the rowkey
del stations['filename']               # no need to keep the duplicate column

stations.head()
# Out:
#                        usafid   wban    yr     lat     long  elev
# filename
# 720262-94076-2015.csv  720262  94076  2015  40.054 -106.368  2259
# 720385-00419-2015.csv  720385    419  2015  39.800 -105.767  4113
# 720385-99999-2015.csv  720385  99999  2015  39.800 -105.767  4113
# 720528-99999-2015.csv  720528  99999  2015  38.817 -106.117  2423
# 720529-00429-2015.csv  720529    429  2015  38.233 -108.567  1811

# %%
# this ought to do for an example cluster.
# restrict to the NE corner of the map.
# here we index with a boolean array (the part inside the square brackets.)

subset = stations[stations.apply(lambda s: s.long > -103.5 and s.lat > 40.5, axis=1)]

# %%
# load them in
dfs = [pd.read_csv("data/csv/" + filename) for filename in subset.index]

# stack them on top of one another
df = pd.concat(dfs)

# lowercase column names
df.columns = map(str.lower, df.columns)

# make filename column for easy reference
df['filename'] = df.apply(construct_filename, axis=1)

df.head()
# Out:
#    usafid   wban    yr  m  d  hr  min     lat     long  elev  wind.dir  \
# 0  720537  99999  2015  1  1   0   15  40.569 -102.273  1137       290
# 1  720537  99999  2015  1  1   0   35  40.569 -102.273  1137       290
# 2  720537  99999  2015  1  1   0   55  40.569 -102.273  1137       290
# 3  720537  99999  2015  1  1   1   15  40.569 -102.273  1137       290
# 4  720537  99999  2015  1  1   1   35  40.569 -102.273  1137       300
#
#    wind.spd  temp  dew.point  atm.pres               filename
# 0       4.6   -10        -17    9999.9  720537-99999-2015.csv
# 1       4.1    -8        -17    9999.9  720537-99999-2015.csv
# 2       4.1   -14        -20    9999.9  720537-99999-2015.csv
# 3       5.1   -12        -18    9999.9  720537-99999-2015.csv
# 4       5.1   -10        -17    9999.9  720537-99999-2015.csv

# %%
# currently that df ^^ has an integer index, but it's time series data.
# let's use pandas builtin datetime indexing capabilities to make life easier.

def construct_timestamp(s):
    """
    Timestamp values are stored in different columns here; yr, m, d, hr, min. 
    We'll do a similar thing with string formatting as above, to get a standard timestamp.
    """
    return "{yr}-{m}-{d} {h}:{min}:00".format(yr=int(s["yr"]), m=int(s["m"]), d=int(s["d"]), h=int(s["hr"]), min=int(s["min"])) 

df.index = pd.DatetimeIndex(df.apply(construct_timestamp, axis=1))  # DatetimeIndex allows lots of cool query patterns.

df.head()
# Out:
#                      usafid   wban    yr  m  d  hr  min     lat     long  \
# 2015-01-01 00:15:00  720537  99999  2015  1  1   0   15  40.569 -102.273
# 2015-01-01 00:35:00  720537  99999  2015  1  1   0   35  40.569 -102.273
# 2015-01-01 00:55:00  720537  99999  2015  1  1   0   55  40.569 -102.273
# 2015-01-01 01:15:00  720537  99999  2015  1  1   1   15  40.569 -102.273
# 2015-01-01 01:35:00  720537  99999  2015  1  1   1   35  40.569 -102.273
#
#                      elev  wind.dir  wind.spd  temp  dew.point  atm.pres  \
# 2015-01-01 00:15:00  1137       290       4.6   -10        -17    9999.9
# 2015-01-01 00:35:00  1137       290       4.1    -8        -17    9999.9
# 2015-01-01 00:55:00  1137       290       4.1   -14        -20    9999.9
# 2015-01-01 01:15:00  1137       290       5.1   -12        -18    9999.9
# 2015-01-01 01:35:00  1137       300       5.1   -10        -17    9999.9
#
#                                   filename
# 2015-01-01 00:15:00  720537-99999-2015.csv
# 2015-01-01 00:35:00  720537-99999-2015.csv
# 2015-01-01 00:55:00  720537-99999-2015.csv
# 2015-01-01 01:15:00  720537-99999-2015.csv
# 2015-01-01 01:35:00  720537-99999-2015.csv

# %%
# find the average temperature among our five clustered stations on January 1. 

df['January 1, 2015'].temp.mean()  # it's cold in northeastern Colorado!!
# Out:
# -13.035416666666668

# %%
df['January 1, 2015'].filename.unique()  # sanity check, yes we have 4/5 stations in attendance.
# Out:
# array(['720537-99999-2015.csv', '720544-00168-2015.csv',
#        '720987-99999-2015.csv', '720991-99999-2015.csv'], dtype=object)

# %% [markdown]
# Forecast.io API
# ---------------
# Now that we have a manageable piece of ISD data in good shape for testing out some queries, let's make some comparisons with what we get back from Forecast.io.
#
# Forecast.io exposes a REST API, which also has a nice Python wrapper available on PyPi and [GitHub](https://github.com/ZeevG/python-forecast.io).

# %%
api_key = "d35a1f70a0f565c5b6015c47140e2a28"
time = pd.datetime(2015, 1, 1, 1)  # 1am on New Year's Day

#nyd = forecastio.load_forecast(api_key, 40.569, -102.273, time=time)

# %%
# look at forecast.io temps, weather cond AT time and coords for each row in Jan 1
# agg by hour and take averages, then get forecast.io at centroid
#
# Out:
#                      usafid   wban    yr  m  d  hr  min     lat     long  \
# 2015-01-01 00:15:00  720537  99999  2015  1  1   0   15  40.569 -102.273
# 2015-01-01 00:35:00  720537  99999  2015  1  1   0   35  40.569 -102.273
# 2015-01-01 00:55:00  720537  99999  2015  1  1   0   55  40.569 -102.273
# 2015-01-01 01:15:00  720537  99999  2015  1  1   1   15  40.569 -102.273
# 2015-01-01 01:35:00  720537  99999  2015  1  1   1   35  40.569 -102.273
# 2015-01-01 01:55:00  720537  99999  2015  1  1   1   55  40.569 -102.273
# 2015-01-01 02:15:00  720537  99999  2015  1  1   2   15  40.569 -102.273
# 2015-01-01 02:35:00  720537  99999  2015  1  1   2   35  40.569 -102.273
# 2015-01-01 02:55:00  720537  99999  2015  1  1   2   55  40.569 -102.273
# 2015-01-01 03:15:00  720537  99999  2015  1  1   3   15  40.569 -102.273
# 2015-01-01 03:35:00  720537  99999  2015  1  1   3   35  40.569 -102.273
# 2015-01-01 03:55:00  720537  99999  2015  1  1   3   55  40.569 -102.273
# 2015-01-01 04:15:00  720537  99999  2015  1  1   4   15  40.569 -102.273
# 2015-01-01 04:35:00  720537  99999  2015  1  1   4   35  40.569 -102.273
# 2015-01-01 04:55:00  720537  99999  2015  1  1   4   55  40.569 -102.273
# 2015-01-01 05:15:00  720537  99999  2015  1  1   5   15  40.569 -102.273
# 2015-01-01 05:35:00  720537  99999  2015  1  1   5   35  40.569 -102.273
# 2015-01-01 05:55:00  720537  99999  2015  1  1   5   55  40.569 -102.273
# 2015-01-01 06:15:00  720537  99999  2015  1  1   6   15  40.569 -102.273
# 2015-01-01 06:35:00  720537  99999  2015  1  1   6   35  40.569 -102.273
# 2015-01-01 06:55:00  720537  99999  2015  1  1   6   55  40.569 -102.273
# 2015-01-01 07:15:00  720537  99999  2015  1  1   7   15  40.569 -102.273
# 2015-01-01 07:35:00  720537  99999  2015  1  1   7   35  40.569 -102.273
# 2015-01-01 07:55:00  720537  99999  2015  1  1   7   55  40.569 -102.273
# 2015-01-01 08:15:00  720537  99999  2015  1  1   8   15  40.569 -102.273
# 2015-01-01 08:35:00  720537  99999  2015  1  1   8   35  40.569 -102.273
# 2015-01-01 08:55:00  720537  99999  2015  1  1   8   55  40.569 -102.273
# 2015-01-01 09:15:00  720537  99999  2015  1  1   9   15  40.569 -102.273
# 2015-01-01 09:35:00  720537  99999  2015  1  1   9   35  40.569 -102.273
# 2015-01-01 09:55:00  720537  99999  2015  1  1   9   55  40.569 -102.273
# ...                     ...    ...   ... .. ..  ..  ...     ...      ...
# 2015-01-01 18:56:00  720987  99999  2015  1  1  18   56  40.967 -103.200
# 2015-01-01 19:56:00  720987  99999  2015  1  1  19   56  40.967 -103.200
# 2015-01-01 20:56:00  720987  99999  2015  1  1  20   56  40.967 -103.200
# 2015-01-01 21:56:00  720987  99999  2015  1  1  21   56  40.967 -103.200
# 2015-01-01 22:56:00  720987  99999  2015  1  1  22   56  40.967 -103.200
# 2015-01-01 23:56:00  720987  99999  2015  1  1  23   56  40.967 -103.200
# 2015-01-01 00:56:00  720991  99999  2015  1  1   0   56  40.700 -103.483
# 2015-01-01 01:56:00  720991  99999  2015  1  1   1   56  40.700 -103.483
# 2015-01-01 02:56:00  720991  99999  2015  1  1   2   56  40.700 -103.483
# 2015-01-01 03:56:00  720991  99999  2015  1  1   3   56  40.700 -103.483
# 2015-01-01 04:56:00  720991  99999  2015  1  1   4   56  40.700 -103.483
# 2015-01-01 05:56:00  720991  99999  2015  1  1   5   56  40.700 -103.483
# 2015-01-01 06:56:00  720991  99999  2015  1  1   6   56  40.700 -103.483
# 2015-01-01 07:56:00  720991  99999  2015  1  1   7   56  40.700 -103.483
# 2015-01-01 08:56:00  720991  99999  2015  1  1   8   56  40.700 -103.483
# 2015-01-01 09:56:00  720991  99999  2015  1  1   9   56  40.700 -103.483
# 2015-01-01 10:56:00  720991  99999  2015  1  1  10   56  40.700 -103.483
# 2015-01-01 11:56:00  720991  99999  2015  1  1  11   56  40.700 -103.483
# 2015-01-01 12:56:00  720991  99999  2015  1  1  12   56  40.700 -103.483
# 2015-01-01 13:56:00  720991  99999  2015  1  1  13   56  40.700 -103.483
# 2015-01-01 14:56:00  720991  99999  2015  1  1  14   56  40.700 -103.483
# 2015-01-01 15:56:00  720991  99999  2015  1  1  15   56  40.700 -103.483
# 2015-01-01 16:56:00  720991  99999  2015  1  1  16   56  40.700 -103.483
# 2015-01-01 17:56:00  720991  99999  2015  1  1  17   56  40.700 -103.483
# 2015-01-01 18:56:00  720991  99999  2015  1  1  18   56  40.700 -103.483
# 2015-01-01 19:56:00  720991  99999  2015  1  1  19   56  40.700 -103.483
# 2015-01-01 20:56:00  720991  99999  2015  1  1  20   56  40.700 -103.483
# 2015-01-01 21:56:00  720991  99999  2015  1  1  21   56  40.700 -103.483
# 2015-01-01 22:56:00  720991  99999  2015  1  1  22   56  40.700 -103.483
# 2015-01-01 23:56:00  720991  99999  2015  1  1  23   56  40.700 -103.483
#
#                      elev  wind.dir  wind.spd  temp  dew.point  atm.pres  \
# 2015-01-01 00:15:00  1137       290       4.6 -10.0      -17.0    9999.9
# 2015-01-01 00:35:00  1137       290       4.1  -8.0      -17.0    9999.9
# 2015-01-01 00:55:00  1137       290       4.1 -14.0      -20.0    9999.9
# 2015-01-01 01:15:00  1137       290       5.1 -12.0      -18.0    9999.9
# 2015-01-01 01:35:00  1137       300       5.1 -10.0      -17.0    9999.9
# 2015-01-01 01:55:00  1137       300       5.1 -10.0      -18.0    9999.9
# 2015-01-01 02:15:00  1137       290       4.1 -10.0      -18.0    9999.9
# 2015-01-01 02:35:00  1137       310       5.1 -10.0      -17.0    9999.9
# 2015-01-01 02:55:00  1137       300       3.6 -10.0      -18.0    9999.9
# 2015-01-01 03:15:00  1137       290       3.6 -11.0      -18.0    9999.9
# 2015-01-01 03:35:00  1137       310       3.1 -11.0      -18.0    9999.9
# 2015-01-01 03:55:00  1137       300       3.6 -11.0      -18.0    9999.9
# 2015-01-01 04:15:00  1137       290       3.1 -11.0      -18.0    9999.9
# 2015-01-01 04:35:00  1137       290       3.6 -15.0      -20.0    9999.9
# 2015-01-01 04:55:00  1137       290       3.6 -15.0      -21.0    9999.9
# 2015-01-01 05:15:00  1137       290       4.1 -15.0      -20.0    9999.9
# 2015-01-01 05:35:00  1137       280       4.1 -15.0      -21.0    9999.9
# 2015-01-01 05:55:00  1137       280       5.1 -15.0      -20.0    9999.9
# 2015-01-01 06:15:00  1137       280       4.6 -15.0      -20.0    9999.9
# 2015-01-01 06:35:00  1137       280       4.6 -15.0      -20.0    9999.9
# 2015-01-01 06:55:00  1137       270       3.6 -15.0      -20.0    9999.9
# 2015-01-01 07:15:00  1137       270       4.6 -15.0      -20.0    9999.9
# 2015-01-01 07:35:00  1137       270       3.6 -15.0      -20.0    9999.9
# 2015-01-01 07:55:00  1137       260       3.1 -15.0      -20.0    9999.9
# 2015-01-01 08:15:00  1137       250       2.6 -15.0      -20.0    9999.9
# 2015-01-01 08:35:00  1137       280       4.6 -17.0      -21.0    9999.9
# 2015-01-01 08:55:00  1137       290       3.6 -15.0      -20.0    9999.9
# 2015-01-01 09:15:00  1137       290       3.6 -15.0      -20.0    9999.9
# 2015-01-01 09:35:00  1137       300       3.6 -15.0      -20.0    9999.9
# 2015-01-01 09:55:00  1137       290       4.6 -13.0      -18.0    9999.9
# ...                   ...       ...       ...   ...        ...       ...
# 2015-01-01 18:56:00  1380       270       3.6  -6.2      -13.7    1022.7
# 2015-01-01 19:56:00  1380       300       4.1  -5.7      -11.9    1021.6
# 2015-01-01 20:56:00  1380       320       4.1  -4.8      -10.7    1021.6
# 2015-01-01 21:56:00  1380       340       4.1  -4.0       -9.9    1020.7
# 2015-01-01 22:56:00  1380       310       3.1  -5.9      -11.3    1021.9
# 2015-01-01 23:56:00  1380       320       3.6  -5.9      -11.3    1022.7
# 2015-01-01 00:56:00  1336       310       3.6 -12.6      -19.8    1033.5
# 2015-01-01 01:56:00  1336       290       3.1 -12.1      -20.2    1032.3
# 2015-01-01 02:56:00  1336       250       2.6 -12.9      -20.4    1032.3
# 2015-01-01 03:56:00  1336       270       4.1 -15.9      -21.5    1032.8
# 2015-01-01 04:56:00  1336       290       5.1 -17.9      -21.8    1032.4
# 2015-01-01 05:56:00  1336       280       5.7 -17.1      -21.3    1031.2
# 2015-01-01 06:56:00  1336       280       5.7 -16.7      -21.1    1029.4
# 2015-01-01 07:56:00  1336       290       4.6 -17.4      -21.4    1028.3
# 2015-01-01 08:56:00  1336       280       5.1 -16.9      -21.0    1027.5
# 2015-01-01 09:56:00  1336       280       4.6 -18.1      -21.7    1026.7
# 2015-01-01 10:56:00  1336       280       5.1 -19.0      -23.2    1026.4
# 2015-01-01 11:56:00  1336       290       5.7 -18.6      -23.4    1025.8
# 2015-01-01 12:56:00  1336       260       4.6 -18.6      -23.2    1025.5
# 2015-01-01 13:56:00  1336       300       3.1 -16.8      -23.1    1025.1
# 2015-01-01 14:56:00  1336       290       4.6 -18.3      -23.3    1025.5
# 2015-01-01 15:56:00  1336       300       3.6 -16.6      -22.5    1027.3
# 2015-01-01 16:56:00  1336       260       2.1 -14.5      -19.6    1026.6
# 2015-01-01 17:56:00  1336       210       4.1 -12.3      -17.9    1026.2
# 2015-01-01 18:56:00  1336       260       3.1 -10.3      -15.6    1024.3
# 2015-01-01 19:56:00  1336       290       3.6  -8.9      -14.0    1023.6
# 2015-01-01 20:56:00  1336       300       2.6  -6.9      -12.6    1022.8
# 2015-01-01 21:56:00  1336       210       4.1  -7.3      -11.8    1023.6
# 2015-01-01 22:56:00  1336       220       2.6  -7.1      -10.6    1024.3
# 2015-01-01 23:56:00  1336       290       3.6  -7.3      -10.4    1024.3
#
#                                   filename
# 2015-01-01 00:15:00  720537-99999-2015.csv
# 2015-01-01 00:35:00  720537-99999-2015.csv
# 2015-01-01 00:55:00  720537-99999-2015.csv
# 2015-01-01 01:15:00  720537-99999-2015.csv
# 2015-01-01 01:35:00  720537-99999-2015.csv
# 2015-01-01 01:55:00  720537-99999-2015.csv
# 2015-01-01 02:15:00  720537-99999-2015.csv
# 2015-01-01 02:35:00  720537-99999-2015.csv
# 2015-01-01 02:55:00  720537-99999-2015.csv
# 2015-01-01 03:15:00  720537-99999-2015.csv
# 2015-01-01 03:35:00  720537-99999-2015.csv
# 2015-01-01 03:55:00  720537-99999-2015.csv
# 2015-01-01 04:15:00  720537-99999-2015.csv
# 2015-01-01 04:35:00  720537-99999-2015.csv
# 2015-01-01 04:55:00  720537-99999-2015.csv
# 2015-01-01 05:15:00  720537-99999-2015.csv
# 2015-01-01 05:35:00  720537-99999-2015.csv
# 2015-01-01 05:55:00  720537-99999-2015.csv
# 2015-01-01 06:15:00  720537-99999-2015.csv
# 2015-01-01 06:35:00  720537-99999-2015.csv
# 2015-01-01 06:55:00  720537-99999-2015.csv
# 2015-01-01 07:15:00  720537-99999-2015.csv
# 2015-01-01 07:35:00  720537-99999-2015.csv
# 2015-01-01 07:55:00  720537-99999-2015.csv
# 2015-01-01 08:15:00  720537-99999-2015.csv
# 2015-01-01 08:35:00  720537-99999-2015.csv
# 2015-01-01 08:55:00  720537-99999-2015.csv
# 2015-01-01 09:15:00  720537-99999-2015.csv
# 2015-01-01 09:35:00  720537-99999-2015.csv
# 2015-01-01 09:55:00  720537-99999-2015.csv
# ...                                    ...
# 2015-01-01 18:56:00  720987-99999-2015.csv
# 2015-01-01 19:56:00  720987-99999-2015.csv
# 2015-01-01 20:56:00  720987-99999-2015.csv
# 2015-01-01 21:56:00  720987-99999-2015.csv
# 2015-01-01 22:56:00  720987-99999-2015.csv
# 2015-01-01 23:56:00  720987-99999-2015.csv
# 2015-01-01 00:56:00  720991-99999-2015.csv
# 2015-01-01 01:56:00  720991-99999-2015.csv
# 2015-01-01 02:56:00  720991-99999-2015.csv
# 2015-01-01 03:56:00  720991-99999-2015.csv
# 2015-01-01 04:56:00  720991-99999-2015.csv
# 2015-01-01 05:56:00  720991-99999-2015.csv
# 2015-01-01 06:56:00  720991-99999-2015.csv
# 2015-01-01 07:56:00  720991-99999-2015.csv
# 2015-01-01 08:56:00  720991-99999-2015.csv
# 2015-01-01 09:56:00  720991-99999-2015.csv
# 2015-01-01 10:56:00  720991-99999-2015.csv
# 2015-01-01 11:56:00  720991-99999-2015.csv
# 2015-01-01 12:56:00  720991-99999-2015.csv
# 2015-01-01 13:56:00  720991-99999-2015.csv
# 2015-01-01 14:56:00  720991-99999-2015.csv
# 2015-01-01 15:56:00  720991-99999-2015.csv
# 2015-01-01 16:56:00  720991-99999-2015.csv
# 2015-01-01 17:56:00  720991-99999-2015.csv
# 2015-01-01 18:56:00  720991-99999-2015.csv
# 2015-01-01 19:56:00  720991-99999-2015.csv
# 2015-01-01 20:56:00  720991-99999-2015.csv
# 2015-01-01 21:56:00  720991-99999-2015.csv
# 2015-01-01 22:56:00  720991-99999-2015.csv
# 2015-01-01 23:56:00  720991-99999-2015.csv
#
# [192 rows x 16 columns]
